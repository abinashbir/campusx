# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer

# %% [markdown]
# CREATING A DATAFRAME FROM A DATASET.

# %%
df=pd.read_csv('/home/abinash-bir/ML/datasets/titanic_toy.csv')
df
# Out:
#       Age     Fare  Family  Survived
# 0    22.0   7.2500       1         0
# 1    38.0  71.2833       1         1
# 2    26.0   7.9250       0         1
# 3    35.0  53.1000       1         1
# 4    35.0   8.0500       0         0
# ..    ...      ...     ...       ...
# 886  27.0  13.0000       0         0
# 887  19.0  30.0000       0         1
# 888   NaN  23.4500       3         0
# 889  26.0      NaN       0         1
# 890  32.0   7.7500       0         0
#
# [891 rows x 4 columns]

# %%
df.shape
# Out:
# (891, 4)

# %%
df.isnull().mean()*100
# Out:
# Age         19.865320
# Fare         5.050505
# Family       0.000000
# Survived     0.000000
# dtype: float64

# %%
mvc = ['Age', 'Fare']

plt.figure(figsize=(10,5))

for i, col in enumerate(mvc, 1):
    plt.subplot(1, 2, i)
    sns.boxplot(x=df[col])
    plt.title(col)

plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import train_test_split

x=df.iloc[:,0:3]
y=df.iloc[:,-1]

# %%
x_train,x_test,v_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
imputer1=SimpleImputer(strategy='median')
imputer2=SimpleImputer(strategy='mean')

# %%
from sklearn.compose import ColumnTransformer

# %%
trf=ColumnTransformer([
    ('imputer1',imputer1,['Age']),
    ('imputer2',imputer2,['Fare'])
],remainder='passthrough')

# %%
trf.fit(x_train)
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('imputer1', SimpleImputer(strategy='median'),
#                                  ['Age']),
#                                 ('imputer2', SimpleImputer(), ['Fare'])])

# %%
x_train=trf.transform(x_train)
x_test=trf.transform(x_test)

# %%
x_train
# Out:
# array([[ 40.    ,  27.7208,   0.    ],
#        [  4.    ,  16.7   ,   2.    ],
#        [ 47.    ,   9.    ,   0.    ],
#        ...,
#        [ 71.    ,  49.5042,   0.    ],
#        [ 28.75  , 221.7792,   0.    ],
#        [ 28.75  ,  25.925 ,   0.    ]], shape=(712, 3))
